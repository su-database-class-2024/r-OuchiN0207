# %% [markdown]
# # SQL for accessing spatial data on postgreSQL

# %% [markdown]
# データベースシステム講義資料
# version 0.0.1
# authors: H. Chenan & N. Tsutsumida
#
# Copyright (c) 2023 Narumasa Tsutsumida
# Released under the MIT license
# https://opensource.org/licenses/mit-license.php

# %% [markdown]
# ## Task

# %% [markdown]
# さいたま市内のコンビニを抽出し地図化する

# %% [markdown]
# ## prerequisites

# %%
import os
from sqlalchemy import create_engine
import pandas as pd
import geopandas as gpd
import numpy as np
import folium
pd.set_option('display.max_columns', 100)
# Out:
# /usr/local/lib/python3.8/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
def query_geopandas(sql, db):
    """
    Executes a SQL query on a postGIS and returns the result as a GeoPandas GeoDataFrame.

    Args:
        sql (str): The SQL query to execute.
        db (str): The name of the PostgreSQL database to connect to.

    Returns:
        geopandas.GeoDataFrame: The result of the SQL query as a GeoPandas GeoDataFrame.
    """
    DATABASE_URL = 'postgresql://postgres:postgres@postgis_container:5432/{}'.format(db)
    conn = create_engine(DATABASE_URL)
    query_result_gdf = gpd.GeoDataFrame.from_postgis(
        sql, conn, geom_col='way') #geom_col='way' when using osm_kanto, geom_col='geom' when using gisdb
    return query_result_gdf

# %% [markdown]
# ## Define a sql command

# %%
sql = """
    select pt.*
    from planet_osm_point pt, adm2 poly
    where pt.shop='convenience' and
    poly.name_2='Saitama' and
    st_within(pt.way,st_transform(poly.geom, 3857));
    """

# %% [markdown]
# ## Outputs

# %%
def display_interactive_map(gdf):
    if gdf.crs != 'EPSG:4326':
        gdf = gdf.to_crs(epsg=4326)
    # Create a base map
    m = folium.Map(location=[35.8616, 139.6455], zoom_start=12)  # You can modify the location as per your dataset

    # Add data points to the map
    for _, row in gdf.iterrows():
        coords = (row['way'].y, row['way'].x)
        folium.Marker(location=coords, popup=row['name']).add_to(m)

    return m

# %%
out = query_geopandas(sql,'gisdb')
map_display = display_interactive_map(out)
print(out)
display(map_display)
# Out:
#           osm_id access addr:housename addr:housenumber addr:interpolation  \
# 0     6795909545   None           None             None               None
# 1     4081142569   None           None             None               None
# 2     6795909641   None           None               13               None
# 3     6898525166   None           None             None               None
# 4     6661634907   None           None             None               None
# ..           ...    ...            ...              ...                ...
# 400   9161249410   None           None             None               None
# 401   9149671133   None           None             None               None
# 402   3744122599   None           None             None               None
# 403   3745337529   None           None             None               None
# 404  12288690630   None           None             None               None
#
#     admin_level aerialway aeroway amenity  area barrier bicycle       brand  \
# 0          None      None    None    None  None    None    None      LAWSON
# 1          None      None    None    None  None    None    None  FamilyMart
# 2          None      None    None    None  None    None    None    セブン-イレブン
# 3          None      None    None    None  None    None    None      ミニストップ
# 4          None      None    None    None  None    None    None    セブン-イレブン
# ..          ...       ...     ...     ...   ...     ...     ...         ...
# 400        None      None    None    None  None    None    None        ローソン
# 401        None      None    None    None  None    None    None        ローソン
# 402        None      None    None    None  None    None    None    セブン-イレブン
# 403        None      None    None    None  None    None    None    セブン-イレブン
# 404        None      None    None    None  None    None    None      LAWSON
#
#     bridge boundary building capital construction covered culvert cutting  \
# 0     None     None     None    None         None    None    None    None
# 1     None     None     None    None         None    None    None    None
# 2     None     None     None    None         None    None    None    None
# 3     None     None     None    None         None    None    None    None
# 4     None     None     None    None         None    None    None    None
# ..     ...      ...      ...     ...          ...     ...     ...     ...
# 400   None     None     None    None         None    None    None    None
# 401   None     None     None    None         None    None    None    None
# 402   None     None     None    None         None    None    None    None
# 403   None     None     None    None         None    None    None    None
# 404   None     None     None    None         None    None    None    None
#
#     denomination disused   ele embankment  foot generator:source harbour  \
# 0           None    None  None       None  None             None    None
# 1           None    None  None       None  None             None    None
# 2           None    None  None       None  None             None    None
# 3           None    None  None       None  None             None    None
# 4           None    None  None       None  None             None    None
# ..           ...     ...   ...        ...   ...              ...     ...
# 400         None    None  None       None  None             None    None
# 401         None    None  None       None  None             None    None
# 402         None    None  None       None  None             None    None
# 403         None    None  None       None  None             None    None
# 404         None    None  None       None  None             None    None
#
#     highway historic horse intermittent junction landuse layer leisure  lock  \
# 0      None     None  None         None     None    None  None    None  None
# 1      None     None  None         None     None    None  None    None  None
# 2      None     None  None         None     None    None  None    None  None
# 3      None     None  None         None     None    None  None    None  None
# 4      None     None  None         None     None    None  None    None  None
# ..      ...      ...   ...          ...      ...     ...   ...     ...   ...
# 400    None     None  None         None     None    None  None    None  None
# 401    None     None  None         None     None    None  None    None  None
# 402    None     None  None         None     None    None  None    None  None
# 403    None     None  None         None     None    None  None    None  None
# 404    None     None  None         None     None    None  None    None  None
#
#     man_made military motorcar              name natural office oneway  \
# 0       None     None     None              ローソン    None   None   None
# 1       None     None     None          ファミリーマート    None   None   None
# 2       None     None     None          セブン-イレブン    None   None   None
# 3       None     None     None            ミニストップ    None   None   None
# 4       None     None     None          セブン-イレブン    None   None   None
# ..       ...      ...      ...               ...     ...    ...    ...
# 400     None     None     None    ローソンさいたま白幡三丁目店    None   None   None
# 401     None     None     None    ローソンさいたま白幡四丁目店    None   None   None
# 402     None     None     None          セブン-イレブン    None   None   None
# 403     None     None     None  セブンイレブンさいたま辻5丁目店    None   None   None
# 404     None     None     None     ローソンさいたま辻五丁目店    None   None   None
#
#     operator place   poi population power power_source public_transport  \
# 0       None  None  None       None  None         None             None
# 1       None  None  None       None  None         None             None
# 2       None  None  None       None  None         None             None
# 3       None  None  None       None  None         None             None
# 4       None  None  None       None  None         None             None
# ..       ...   ...   ...        ...   ...          ...              ...
# 400     None  None  None       None  None         None             None
# 401     None  None  None       None  None         None             None
# 402     None  None  None       None  None         None             None
# 403     None  None  None       None  None         None             None
# 404     None  None  None       None  None         None             None
#
#     railway   ref religion route service         shop sport surface  toll  \
# 0      None  None     None  None    None  convenience  None    None  None
# 1      None  None     None  None    None  convenience  None    None  None
# 2      None  None     None  None    None  convenience  None    None  None
# 3      None  None     None  None    None  convenience  None    None  None
# 4      None  None     None  None    None  convenience  None    None  None
# ..      ...   ...      ...   ...     ...          ...   ...     ...   ...
# 400    None  None     None  None    None  convenience  None    None  None
# 401    None  None     None  None    None  convenience  None    None  None
# 402    None  None     None  None    None  convenience  None    None  None
# 403    None  None     None  None    None  convenience  None    None  None
# 404    None  None     None  None    None  convenience  None    None  None
#
#     tourism tower:type tunnel water waterway wetland width  wood z_order  \
# 0      None       None   None  None     None    None  None  None    None
# 1      None       None   None  None     None    None  None  None    None
# 2      None       None   None  None     None    None  None  None    None
# 3      None       None   None  None     None    None  None  None    None
# 4      None       None   None  None     None    None  None  None    None
# ..      ...        ...    ...   ...      ...     ...   ...   ...     ...
# 400    None       None   None  None     None    None  None  None    None
# 401    None       None   None  None     None    None  None  None    None
# 402    None       None   None  None     None    None  None  None    None
# 403    None       None   None  None     None    None  None  None    None
# 404    None       None   None  None     None    None  None  None    None
#
#                                   way
# 0    POINT (15540181.501 4295281.306)
# 1    POINT (15539656.930 4295032.874)
# 2    POINT (15540543.356 4293188.963)
# 3    POINT (15540249.662 4293338.940)
# 4    POINT (15540245.020 4293894.136)
# ..                                ...
# 400  POINT (15546168.964 4279206.824)
# 401  POINT (15546190.282 4278690.677)
# 402  POINT (15545980.422 4278310.304)
# 403  POINT (15546662.688 4277948.536)
# 404  POINT (15546781.589 4277766.847)
#
# [405 rows x 70 columns]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de7b4f9f21357236309755c7dd82b5ab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de7b4f9f21357236309755c7dd82b5ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de7b4f9f21357236309755c7dd82b5ab = L.map(
#                 &quot;map_de7b4f9f21357236309755c7dd82b5ab&quot;,
#                 {
#                     center: [35.8616, 139.6455],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_472796910dd3dee81003b3a4ac0bfe71 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_de7b4f9f21357236309755c7dd82b5ab);
#
#
#             var marker_6d2a67e57886f4b7962bf920c54d9768 = L.marker(
#                 [35.96118139973169, 139.5998256],
#                 {}
#             ).addTo(map_de7b4f9f21357236309755c7dd82b5ab);
#
#
#         var popup_2bbd73e950ba721033db1951f7bc4bef = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_610d008630842c9474422584d7b0dbce = $(`&lt;div id=&quot;html_610d008630842c9474422584d7b0dbce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ローソン&lt;/div&gt;`)[0];
#                 popup_2bbd73e950ba721033db1951f7bc4bef.setContent(html_610d008630842c9474422584d7b0dbce);
#
#
#
#         marker_6d2a67e57886f4b7962bf920c54d9768.bindPopup(popup_2bbd73e950ba721033db1951f7bc4bef)
#         ;
#
#
#
#
#             var marker_34b0613829c50f9f460e7c595bffc9ac = L.marker(
#                 [35.95937499973153, 139.5951133],
#                 {}
#             ).addTo(map_de7b4f9f21357236309755c7dd82b5ab);
#
#
#         var popup_2b5c372db8bf420a1ca9b6d09b78c873 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_da2f689ccade672f534ebb6516c84871 = $(`&lt;div id=&quot;html_da2f689ccade672f534ebb6516c84871&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ファミリーマート&lt;/div&gt;`)[0];
#                 popup_2b5c372db8bf420a1ca9b6d09b78c873.setContent(html_da2f689ccade672f534ebb6516c84871);
#
#
#
#         marker_34b0613829c50f9f460e7c595bffc9ac.bindPopup(popup_2b5c372db8bf420a1ca9b6d09b78c873)
#         ;
#
#
#
#
#             var marker_8e25d47f0e7713d8f557b594c59637f5 = L.marker(
#                 [35.94596629973021, 139.6030762],
#                 {}
#             ).addTo(map_de7b4f9f21357236309755c7dd82b5ab);
#
#
#         var popup_f4a7e6e6a9c67df57b10aac13809917f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_74870e3b6b530d4ff5c7ad6ff062357e = $(`&lt;div id=&quot;html_74870e3b6b530d4ff5c7ad6ff062357e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;セブン-イレブン&lt;/div&gt;`)[0];
#                 popup_f4a7e6e6a9c67df57b10aac13809917f.setContent(html_74870e3b6b530d4ff5c7ad6ff062357e);
#
#
#
#         marker_8e25d47f0e7713d8f557b594c59637f5.bindPopup(popup_f4a7e6e6a9c67df57b10aac13809917f)
#         ;
#
#
#
#
#             var marker_501b8c683986e6c5d841fef8382f545c = L.marker(
#                 [35.94705699973032, 139.6004379],
#                 {}
#             ).addTo(map_de7b4f9f21357236309755c7dd82b5ab);
#
#
#         var popup_5613ceba14a1817fe682f55aae45e53f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f3ee106e1a2cf48f41c9b29929b56bd4 = $(`&lt;div id=&quot;html_f3ee106e1a2cf48f41c9b29929b56bd4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ミニストップ&lt;/div&gt;`)[0];
#                 popup_5613ceba14a1817fe682f55aae45e53f.setContent(html_f3ee106e1a2cf48f41c9b29929b56bd4);
#
#
#
#         marker_501b8c683986e6c5d841fef8382f545c.bindPopup(popup_5613ceba14a1817fe682f55aae45e53f)
#         ;
#
#
#
#
#             var marker_afa489146faeae7b419093db7bf5278c = L.marker(
#                 [35.95109449973071, 139.6003962],
#                 {}
#             ).addTo(map_de7b4f9f21357236309755c7dd82b5ab);
#
#
#         var popup_dc6e9c57466566631f3e9bc6e6bd00bd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1b83e060cf2e4c57918d163313b0093c = $(`&lt;div id=&quot;html_1b83e060cf2e4c57918d163313b0093c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;セブン-イレブン&lt;/div&gt;`)[0];
#                 popup_dc6e9c57466566631f3e9bc6e6bd00bd.setContent(html_1b83e060cf2e4c57918d163313b0093c);
#
#
#
#         marker_afa489146faeae7b419093db7bf5278c.bindPopup(popup_dc6e9c57466566631f3e9bc6e6bd00bd)
#         ;
#
#
#
#
#             var marker_f83d7a41076f87009a5fea4cf87a55a1 = L.marker(
#                 [35.950547599730655, 139
